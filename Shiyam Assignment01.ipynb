# %% [markdown]
# # **MINDFULAI'S INTERNSHIP ASSIGNMENT 1**

# %% [markdown]
# ## **TOPIC : - Introduction of LLM & Overview of Lanchain**

# %% [markdown]
# ## 10 Popular Large Language Models (LLMs)
#
# * **GPT-3**
# * **LaMDA**
# * **Bard**
# * **Meena**
# * **Turing NLG**
# * **DialoGPT**
# * **Bloom**
# * **Generative Pre-trained Transformer 3**
# * **PaLM**
# * **XLM-RoBERTa**
#
# bold text

# %% [markdown]
# ### *WRITE 10 APPLICATION NAME THAT CAN BE CREATED USING LLM?*
#
#
# > Question Answering Systems
#
# > Code Generation and Debugging
#
# > Improving Search Engines
#
# > Fraud Detection and Cybersecurity
#
# > Medical Diagnosis and Treatment
#
# > Data Engineering
#
# > Data Science and AI Solution
#
# > Data Strategy
#
# > Generative AI/NLP
#
# > Education and Learning

# %% [markdown]
# ## 1. LLMs
#
# A generic interface for all LLMs. See all LLM providers: https://python.langchain.com/en/latest/modules/models/llms/integrations.html

# %% [markdown]
# ```
# START INTEGRATING 5 DIFFERENT LLM MODEL IN LANGCHAIN
# ```
#
#
#
# > *SIMPLE EXAMPLE I HAVE GIVE BELOW*

# %% [markdown]
# > **1. Flan-Alpaca-large LLM**

# %%
# !pip install langchain
# !pip install huggingface_hub

# %%
 import os
 os.environ["HUGGINGFACEHUB_API_TOKEN"]="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"

# %%
from langchain.prompts import PromptTemplate
from langchain import HuggingFaceHub

# %%
llm = HuggingFaceHub(repo_id="declare-lab/flan-alpaca-large",model_kwargs={"temperature":0,"max_length": 512})

# %%
prompt_template = PromptTemplate(
    template = "Tell me a catchy name for chocolate shop that makes {chocolates}",
    input_variables=["chocolates"]
)

# %%
from langchain.chains import LLMChain

# %%
chain = LLMChain(llm=llm, prompt=prompt_template)

# %%
print(chain.run("choco lush"))
# Out:
# Luxurious Chocolates.

# %% [markdown]
# **2. Flan-t5-small**

# %%
# !pip install langchain
# !pip install huggingface_hub

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"]="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"

# %%
from langchain.prompts import PromptTemplate
from langchain import HuggingFaceHub

# %%
llm = HuggingFaceHub(repo_id="google/flan-t5-small",model_kwargs={"temperature":0,"max_length": 512})

# %%
prompt_template = PromptTemplate(
    template = "Who is the indian cricket team captain??{Question}",
    input_variables=["Question"]
)

# %%
from langchain.chains import LLMChain

# %%
chain = LLMChain(llm=llm, prompt=prompt_template)

# %%
question = "Who is the indian cricket team captain??"
print(chain.run("question"))
# Out:
# Sachin Tendulkar

# %% [markdown]
# **3. Flan-t5-large**

# %%
# !pip install langchain
# !pip install huggingface_hub

# %%
 import os
 os.environ["HUGGINGFACEHUB_API_TOKEN"]="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"

# %%
from langchain.prompts import PromptTemplate
from langchain import HuggingFaceHub

# %%
llm = HuggingFaceHub(repo_id="google/flan-t5-large",model_kwargs={"temperature":0,"max_length": 64})

# %%
prompt_template = PromptTemplate(
    template = "What is the capital of Tamilnadu{Question}",
    input_variables=["Question"]
)

# %%
from langchain.chains import LLMChain

# %%
chain = LLMChain(llm=llm, prompt=prompt_template)

# %%
question = "What is the capital of Tamilnadu?"
print(chain.run("question"))
# Out:
# chennai

# %% [markdown]
# **4. Flan-t5-xl**

# %%
# !pip install langchain
# !pip install huggingface_hub

# %%
 import os
 os.environ["HUGGINGFACEHUB_API_TOKEN"]="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"

# %%
from langchain.prompts import PromptTemplate
from langchain import HuggingFaceHub

# %%
llm = HuggingFaceHub(repo_id="google/flan-t5-xl",model_kwargs={"temperature":0,"max_length": 512})

# %%
prompt_template = PromptTemplate(
    template = "Who is the president of India{Question}",
    input_variables=["Question"]
)

# %%
from langchain.chains import LLMChain

# %%
chain = LLMChain(llm=llm, prompt=prompt_template)

# %%
question = "Who is the president of England?"
print(chain.run("question"))
# Out:
# samantha kumar

# %% [markdown]
# **5. Falcon 7B**

# %%
# !pip install langchain
# !pip install huggingface_hub

# %%
 import os
 os.environ["HUGGINGFACEHUB_API_TOKEN"]="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"

# %%
from langchain.prompts import PromptTemplate
from langchain import HuggingFaceHub

# %%
llm = HuggingFaceHub(repo_id="tiiuae/falcon-7b-instruct",model_kwargs={"temperature":0.3,"max_length": 512})

# %%
prompt_template = PromptTemplate(
    template = "Names for a shop which makes {cakes}",
    input_variables=["cakes"]
)

# %%
from langchain.chains import LLMChain

# %%
chain = LLMChain(llm=llm, prompt=prompt_template)

# %%
print(chain.run("cakes"))
# Out:
#  for weddings
# There are many names you could choose for your cake shop that makes cakes for weddings.

# %% [markdown]
# **6. Blender Bot**

# %%
# !pip -q install langchain huggingface_hub transformers sentence_transformers

# %%
import os
os.environ['HUGGINGFACEHUB_API_TOKEN'] = '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'

# %%
from langchain.llms import HuggingFacePipeline
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline, AutoModelForSeq2SeqLM

model_id = 'facebook/blenderbot-1B-distill'
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForSeq2SeqLM.from_pretrained(model_id)

pipe = pipeline(
    "text2text-generation",
    model=model,
    tokenizer=tokenizer,
    max_length=100
)

local_llm = HuggingFacePipeline(pipeline=pipe)

# %%
llm_chain = LLMChain(prompt=prompt,
                     llm=local_llm
                     )

question = "What area is best for growing wine in France?"

print(llm_chain.run(question))
# Out:
#  I'm not sure, but I do know that France is one of the largest producers of wine in the world.

# %% [markdown]
# **7. GPT2 - Medium**

# %%
# !pip -q install langchain huggingface_hub transformers sentence_transformers

# %%
import os
os.environ['HUGGINGFACEHUB_API_TOKEN'] = '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'

# %%
model_id = "gpt2-medium"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id)

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_length=100
)

llm = HuggingFacePipeline(pipeline=pipe)
# Out:
# ...
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
chain = LLMChain(prompt=prompt,
                     llm=llm
                     )

question = "Facts about  New Zealand cricket team?"
print(chain.run(question))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  One might argue that it's a part of New Zealand Cricket that provides the players with a nice salary and that makes up the rest of the income. We should be happy if we got more funds that we could spend on the players (with financial stability guaranteed).
#
# That doesn't mean we would put the money on the players though, because let's be honest, we don't spend our

# %% [markdown]
# **8. Flan-alpaco-large**

# %%
# !pip install langchain
# !pip install huggingface_hub

# %%
import os
os.environ['HUGGINGFACEHUB_API_TOKEN'] = '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'

# %%
from langchain.prompts import PromptTemplate
from langchain import HuggingFaceHub

# %%
llm = HuggingFaceHub(repo_id="declare-lab/flan-alpaca-large",model_kwargs={"temperature":0,"max_length": 512})

# %%
prompt_template = PromptTemplate(
    template = "What is the national bird of india?{Question}",
    input_variables=["Question"]
)

# %%
from langchain.chains import LLMChain

# %%
chain = LLMChain(llm=llm,prompt=prompt_template)

# %%
question = "What is the national bird of india?"
print(chain.run("question"))
# Out:
# The national bird of India is the Indian tamarin.
